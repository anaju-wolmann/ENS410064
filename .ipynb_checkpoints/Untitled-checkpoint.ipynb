# %% [markdown]
# # Ana na casa dos dragões

# %%
Instalar a biblioteca que usaremos na próxima aula para importar e analisar nossa série temporal

Para instalar pacotes aqui, no Jupyter, vamos usar a notação "!", sem aspas, e o comando de instalação

# %%
# !pip install pandas

# %%
# Importando o pandas
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\najuw\\OneDrive\\Documentos\\GitHub\\ENS410064\\pyEnv\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
# Ler o arquivo de base
df = pd.read_csv(r"C:\Users\najuw\OneDrive\Documentos\GitHub\ENS410064\dados_de_entrada\SC.csv",encoding='latin1')
df
# Out:
#          Ano  Mes  Dia  Hora  Minuto            Estacao  Codigo Poluente  \
# 0       2023    1    1     0      30  Capivari de Baixo  SC_002      PTS
# 1       2023    1    1     1      30  Capivari de Baixo  SC_002      PTS
# 2       2023    1    1     2      30  Capivari de Baixo  SC_002      PTS
# 3       2023    1    1     3      30  Capivari de Baixo  SC_002      PTS
# 4       2023    1    1     4      30  Capivari de Baixo  SC_002      PTS
# ...      ...  ...  ...   ...     ...                ...     ...      ...
# 201475  2023   12   31    19      30         Vila Moema  SC_001       CO
# 201476  2023   12   31    20      30         Vila Moema  SC_001       CO
# 201477  2023   12   31    21      30         Vila Moema  SC_001       CO
# 201478  2023   12   31    22      30         Vila Moema  SC_001       CO
# 201479  2023   12   31    23      30         Vila Moema  SC_001       CO
#
#           Valor Unidade        Tipo    Testacao
# ...
